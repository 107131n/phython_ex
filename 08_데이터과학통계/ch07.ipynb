# %%
# 연속형 확률변수
# -1차원 연속형 확률변수
# -2차원 연속형 확률변수

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
import warnings
warnings.filterwarnings('ignore',category=integrate.IntegrationWarning)

# %%
# 1차원 연속형 확률변수
# 연속형 확률변수
# 확률변수가 취할 수 있는 값이 연속적인 확률변수
# 특정 값을 취하는 확률은 정의되지 않음
# 확률변수가 어느 구간에 들어가는 확률을 정의 -> 범위값 필요
# ex) 룰렛

# %%
# 확률밀도함수
# 확률변수가 취할 수 있는 구간 [a,b]
# 확률은 확률밀도함수 또는 밀도함수에 의해 정의
# 어떤 특정 값을 취하는 확률로는 정의되지 않음

# %%
x_range = np.array([0,1])

# %%
def f(x):
    if x_range[0] <= x <= x_range[1]:
        return 2*x
    else:
        return 0

# %%
X = [x_range,f]

# %%
plt.rcParams['axes.unicode_minus'] = False # -가 깨질 때

xs = np.linspace(x_range[0],x_range[1],100) # linspace: 균등하게 나눌 때
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(xs,[f(x) for x in xs],label='f(x)',color='gray')
ax.hlines(0,-0.2,1.2,alpha=0.3)
ax.vlines(0,-0.2,2.2,alpha=0.3)
ax.vlines(xs.max(),0,2.2,linestyles=':',color='gray')
xs = np.linspace(0.4,0.6,100)
ax.fill_between(xs, [f(x) for x in xs], label = 'prob')
ax.set_xticks(np.arange(-0.2,1.3,0.1)) # set_xticks: x축 눈금
ax.set_xlim(-0.1,1.1) # 제한
ax.set_ylim(-0.2,2.1)
ax.legend()

plt.show()

# %%
# %precision 3
# Out:
# '%.3f'

# %%
integrate.quad(f,0.4,0.6)
# Out:
# (0.200, 0.000)

# %%
from scipy.optimize import minimize_scalar

# %%
minimize_scalar(f)
# Out:
#      fun: 0
#  message: '\nOptimization terminated successfully;\nThe returned value satisfies the termination criteria\n(using xtol = 1.48e-08 )'
#     nfev: 41
#      nit: 37
#  success: True
#        x: -1.6180339754913822

# %%
integrate.quad(f,-np.inf,np.inf) # 적분
# Out:
# (1.000, 0.000)

# %%
def F(x):
    return integrate.quad(f,-np.inf,x)[0]

# %%
F(0.4)
# Out:
# 0.160

# %%
F(0.6)
# Out:
# 0.360

# %%
F(0.6)-F(0.4) # 0.4 ~ 0.6 면적
# Out:
# 0.200

# %%
xs = np.linspace(x_range[0],x_range[1],100)

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

ax.plot(xs, [F(x) for x in xs], label='F(x)',color='gray')

ax.hlines(0,-0.2,1.2,alpha=0.3)
ax.vlines(0,-0.2,2.2,alpha=0.3)
ax.vlines(xs.max(),0,2.2,linestyles=':',color='gray')

ax.set_xticks(np.arange(-0.2,1.3,0.1)) # set_xticks: x축 눈금
ax.set_xlim(-0.1,1.1) # 제한
ax.set_ylim(-0.2,1.1)
ax.legend()

plt.show()

# %%
# 확률변수의 변환
# x가 연속형 확률변수
# y = 2x+3인 y도 연속형 확률변수
# y의 확률밀도함수 g(y) = (y-3)/2

# %%
y_range = [3,5]
def g(y):
    if y_range[0] <= y <= y_rnagte[1]:
        return (y-3)/2
    else:
        return o
def G(y):
    return integrate.quad(g,-np.inf,y)[0]

# %%
def integrand(x):
    return x * f(x)

# %%
integrate.quad(integrand,-np.inf,np.inf)[0]
# Out:
# 0.667

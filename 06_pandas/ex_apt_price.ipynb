# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# %pwd #워킹디렉토리 확인. Print Working Directory. 현재 디렉토리를 알려주는 명령어
# Out:
# 'C:\\gitwd\\phython_ex\\06_pandas'

# %%
first_df = pd.read_csv('data/전국_평균_분양가격(2013년_9월부터_2015년_8월까지).csv',
            encoding='cp949')

# %%
first_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
# ...

# %%
last_df = pd.read_csv('data/주택도시보증공사_전국_평균_분양가격(2019년_12월).csv',
            encoding='cp949')

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
last_df.head(2)
# Out:
#   지역명        규모구분    연도   월 분양가격(㎡)
# 0  서울          전체  2015  10    5841
# 1  서울  전용면적 60㎡이하  2015  10    5652

# %%
last_df.tail(2)
# Out:
#      지역명               규모구분    연도   월 분양가격(㎡)
# 4333  제주  전용면적 85㎡초과 102㎡이하  2019  12     NaN
# 4334  제주        전용면적 102㎡초과  2019  12    3601

# %%
last_df.isnull().sum() #결측치(얼마나 비어있는지) 확인 <-> notnull
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# dtype: int64

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
True + True + False
# Out:
# 2

# %%
first_df.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 169.5+ KB

# %%
# last_df['분양가격(㎡)'].sum()

# %%
# last_df['분양가격(㎡)'].astype(int) # ''로 인해서 int로 변경 불가

# %%
pd.to_numeric(last_df['분양가격(㎡)'],errors = 'coerce') # 'coerce'는 문제 있으면 NaN으로 대체, NaN은 실수형으로 변환 가능
# Out:
# 0       5841.0
# 1       5652.0
# 2       5882.0
# 3       5721.0
# 4       5879.0
#          ...
# 4330    3882.0
# 4331       NaN
# 4332    3898.0
# 4333       NaN
# 4334    3601.0
# Name: 분양가격(㎡), Length: 4335, dtype: float64

# %%
last_df['분양가격'] = pd.to_numeric(last_df['분양가격(㎡)'],errors = 'coerce')

# %%
last_df.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    277
# 분양가격       378
# dtype: int64

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 203.3+ KB

# %%
type(np.NaN) # 넘파이에서 NaN 지원, NaN 타입은 실수형
# Out:
# float

# %%
last_df['분양가격'].sum()
# Out:
# 12813275.0

# %%
last_df['분양가격'].mean()
# Out:
# 3238.128632802628

# %%
# 2013 ~ 2015 데이터 평당 분양 가격, 2015 ~ 2019 ㎡당 분양 가격 #단위 통일 필요

# %%
last_df['평당 분양가격'] = last_df['분양가격'] * 3.3 #평당 분양 가격으로 변환

# %%
last_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당 분양가격  3957 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 237.2+ KB

# %%
last_df['분양가격(㎡)'].describe() # 요약/ obj형은 unique 유일값 개수 알려줌
# Out:
# count     4058
# unique    1753
# top       2221
# freq        17
# Name: 분양가격(㎡), dtype: object

# %%
last_df['분양가격'].describe() # 요약/ 수치형 데이터는 개수, 평균...
# Out:
# count     3957.000000
# mean      3238.128633
# std       1264.309933
# min       1868.000000
# 25%       2441.000000
# 50%       2874.000000
# 75%       3561.000000
# max      12728.000000
# Name: 분양가격, dtype: float64

# %%
last_df['분양가격(㎡)'].nunique() # 유일값 개수 계산
# Out:
# 1753

# %%
# 규모구분
last_df['규모구분'].unique() # 유일값을 보여줌/ 규모구분은 뒤 데이터에만 있음
# Out:
# array(['전체', '전용면적 60㎡이하', '전용면적 60㎡초과 85㎡이하', '전용면적 85㎡초과 102㎡이하',
#        '전용면적 102㎡초과'], dtype=object)

# %%
last_df['전용면적']=last_df['규모구분'].str.replace('전용면적','') # replace는 데이터의 전체가 일치하는 것을 찾음, 그래서 전용면적이 다 지워지지 않음, '전체'가 있어서
last_df['전용면적']=last_df['전용면적'].str.replace('초과','~')
last_df['전용면적']=last_df['전용면적'].str.replace('이하','')
last_df['전용면적']=last_df['전용면적'].str.replace(' ','').str.strip() # 스트립만 쓰면 가운데 공백은 제거 못 함
last_df['전용면적']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '규모구분'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# 필요없는 컬럼 제거

# %%
last_df.columns
# Out:
# Index(['지역명', '규모구분', '연도', '월', '분양가격(㎡)', '분양가격', '평당 분양가격', '전용면적'], dtype='object')

# %%
last_df.info() # memory usage: 271.1+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   규모구분     4335 non-null   object
#  2   연도       4335 non-null   int64
#  3   월        4335 non-null   int64
#  4   분양가격(㎡)  4058 non-null   object
#  5   분양가격     3957 non-null   float64
#  6   평당 분양가격  3957 non-null   float64
#  7   전용면적     4335 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 271.1+ KB

# %%
last_df.drop(columns=['규모구분','분양가격(㎡)'],inplace = True)

# %%
last_df.info() # memory usage: 203.3+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4335 entries, 0 to 4334
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      4335 non-null   object
#  1   연도       4335 non-null   int64
#  2   월        4335 non-null   int64
#  3   분양가격     3957 non-null   float64
#  4   평당 분양가격  3957 non-null   float64
#  5   전용면적     4335 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 203.3+ KB

# %%
# groupby() 데이터 집계

# %%
# last_df.groupby? # shift+tab, ?로 설명창 확인 가능

# %%
last_df.head()
# Out:
#   지역명    연도   월    분양가격  평당 분양가격        전용면적
# 0  서울  2015  10  5841.0  19275.3          전체
# 1  서울  2015  10  5652.0  18651.6         60㎡
# 2  서울  2015  10  5882.0  19410.6   60㎡ ~ 85㎡
# 3  서울  2015  10  5721.0  18879.3  85㎡ ~ 102㎡
# 4  서울  2015  10  5879.0  19400.7      102㎡ ~

# %%
# 지역별 평당 분양가격의 평균

# %%
last_df.groupby(['지역명'])['평당 분양가격'].mean()
# Out:
# 지역명
# 강원     7890.750000
# 경기    13356.895200
# 경남     9268.778138
# 경북     8376.536515
# 광주     9951.535821
# 대구    11980.895455
# 대전    10253.333333
# 부산    12087.121200
# 서울    23599.976400
# 세종     9796.516456
# 울산    10014.902013
# 인천    11915.320732
# 전남     7565.316532
# 전북     7724.235484
# 제주    11241.276712
# 충남     8233.651883
# 충북     7634.655600
# Name: 평당 분양가격, dtype: float64

# %%
# 전용면적의 전체만 가져와 지역별 평당 분양가격의 평균

# %%
last_df[last_df['전용면적']=='전체'].groupby(['지역명'])['평당 분양가격'].mean()
# Out:
# 지역명
# 강원     7477.536000
# 경기    12559.602000
# 경남     8658.672000
# 경북     8078.532000
# 광주     9903.630000
# 대구    11771.298000
# 대전     9786.018000
# 부산    11936.166000
# 서울    22610.346000
# 세종     9805.422000
# 울산    10492.712195
# 인천    11257.026000
# 전남     7283.562000
# 전북     7292.604000
# 제주    10784.994000
# 충남     7815.324000
# 충북     7219.014000
# Name: 평당 분양가격, dtype: float64

# %%
# 전용면적별 평당 분양 가격

# %%
last_df.groupby(['전용면적'])['평당 분양가격'].mean()
# Out:
# 전용면적
# 102㎡ ~        11517.705634
# 60㎡           10375.137421
# 60㎡ ~ 85㎡     10271.040071
# 85㎡ ~ 102㎡    11097.599573
# 전체            10276.086207
# Name: 평당 분양가격, dtype: float64

# %%
# 전용면적, 지역명 별 평당 분양 가격의 평균

# %%
last_df.groupby(['전용면적','지역명'])['평당 분양가격'].mean()
# Out:
# 전용면적    지역명
# 102㎡ ~  강원      8311.380000
#         경기     14771.790000
#         경남     10358.363265
#         경북      9157.302000
#         광주     11041.532432
#                    ...
# 전체      전남      7283.562000
#         전북      7292.604000
#         제주     10784.994000
#         충남      7815.324000
#         충북      7219.014000
# Name: 평당 분양가격, Length: 85, dtype: float64

# %%
last_df.groupby(['지역명','전용면적'])['평당 분양가격'].mean().unstack().round() # 언스택: 그룹바이에서 지역명, 전용면적 중 뒤인 전용면적을 컬럼으로 올려줌, 피봇과 비슷
# Out:
# 전용면적   102㎡ ~      60㎡  60㎡ ~ 85㎡  85㎡ ~ 102㎡       전체
# 지역명
# 강원     8311.0   7567.0     7486.0      8750.0   7478.0
# 경기    14772.0  13252.0    12524.0     13678.0  12560.0
# 경남    10358.0   8689.0     8619.0     10018.0   8659.0
# 경북     9157.0   7883.0     8061.0      8774.0   8079.0
# 광주    11042.0   9431.0     9911.0      9296.0   9904.0
# 대구    13087.0  11992.0    11779.0     11141.0  11771.0
# 대전    14877.0   9176.0     9711.0      9037.0   9786.0
# 부산    13208.0  11354.0    11865.0     12073.0  11936.0
# 서울    23446.0  23213.0    22787.0     25944.0  22610.0
# 세종    10107.0   9324.0     9775.0      9848.0   9805.0
# 울산     9974.0   9202.0    10503.0      8861.0  10493.0
# 인천    14362.0  11241.0    11384.0     11528.0  11257.0
# 전남     8168.0   7210.0     7269.0      7909.0   7284.0
# 전북     8194.0   7610.0     7271.0      8276.0   7293.0
# 제주    10523.0  14022.0    10621.0     10709.0  10785.0
# 충남     8689.0   7911.0     7819.0      9120.0   7815.0
# ...

# %%
last_df.groupby(['연도','지역명'])['평당 분양가격'].mean().unstack().T # T: 행과 열을 바꿈, transpose
# Out:
# 연도        2015          2016          2017          2018          2019
# 지역명
# 강원    7188.060   7162.903846   7273.560000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12304.980000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8786.760000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8280.800000   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9613.977551   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12206.700000  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9957.158491  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11560.680000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21831.060000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.505556  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10666.935714  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11640.600000  11881.532143  13249.775000
# ...

# %%
# 피벗 테이블로 지역별 평당 분양가격의 평균

# %%
pd.pivot_table
# Out:
# <function pandas.core.reshape.pivot.pivot_table(data: 'DataFrame', values=None, index=None, columns=None, aggfunc: 'AggFuncType' = 'mean', fill_value=None, margins: 'bool' = False, dropna: 'bool' = True, margins_name: 'str' = 'All', observed: 'bool' = False, sort: 'bool' = True) -> 'DataFrame'>

# %%
last_df.pivot_table(values = '평당 분양가격' , index = '지역명', aggfunc = 'max' ) # aggfunc: 집계를 내서 어떤 함수를 쓸 건지/ 그룹바이와 차이점: 그룹바이는 시리즈로 나오고 피벗은 데이터프레임으로 나옴
# Out:
#      평당 분양가격
# 지역명
# 강원   11873.4
# 경기   18711.0
# 경남   14199.9
# 경북   11408.1
# 광주   16107.3
# 대구   17021.4
# 대전   16094.1
# 부산   15255.9
# 서울   42002.4
# 세종   12972.3
# 울산   11860.2
# 인천   17120.4
# 전남   10074.9
# 전북   10071.6
# 제주   18024.6
# 충남   10563.3
# 충북    9421.5

# %%
# 전용면적별 평당 분양가격의 평균

# %%
last_df.pivot_table(values = '평당 분양가격', index = '전용면적')
# Out:
#                  평당 분양가격
# 전용면적
# 102㎡ ~      11517.705634
# 60㎡         10375.137421
# 60㎡ ~ 85㎡   10271.040071
# 85㎡ ~ 102㎡  11097.599573
# 전체          10276.086207

# %%
# 전용면적, 지역별 평당 분양가격

# %%
last_df.pivot_table(index= ['전용면적','지역명'], values = '평당 분양가격')
# Out:
#                  평당 분양가격
# 전용면적   지역명
# 102㎡ ~ 강원    8311.380000
#        경기   14771.790000
#        경남   10358.363265
#        경북    9157.302000
#        광주   11041.532432
# ...                  ...
# 전체     전남    7283.562000
#        전북    7292.604000
#        제주   10784.994000
#        충남    7815.324000
#        충북    7219.014000
#
# [85 rows x 1 columns]

# %%
# 연도, 지역별 평당 분양가격

# %%
last_df.pivot_table(index = ['연도','지역명'], values = '평당 분양가격').reset_index().set_index('연도')
# Out:
#      지역명       평당 분양가격
# 연도
# 2015  강원   7188.060000
# 2015  경기  11060.940000
# 2015  경남   8459.220000
# 2015  경북   7464.160000
# 2015  광주   7916.700000
# ...   ..           ...
# 2019  전남   8219.275862
# 2019  전북   8532.260000
# 2019  제주  11828.469231
# 2019  충남   8748.840000
# 2019  충북   7970.875000
#
# [85 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'NanumSquare Neo Light' #'Malgun Gothic'
plt.rcParams['font.size'] = 10
plt.rcParams['axes.unicode_minus'] = False

# %%
g = last_df.groupby(['지역명'])['평당 분양가격'].mean().to_frame() # to_frame(): 시리즈를 프레임으로 변경

# %%
g.plot()
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
g.plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='지역명'>

# %%
g.plot.barh()
# Out:
# <AxesSubplot:ylabel='지역명'>

# %%
g.plot.bar(rot=90, figsize = (8,4)) # rot: 회전 각도 / figsize: 기본 크기 지정
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
g = last_df.groupby(['지역명'])['평당 분양가격'].mean().sort_values(ascending=False).to_frame()

# %%
g.plot.bar(rot = 0,figsize = (10,3))
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
# 연도별 평당 분양가격

# %%
yp = last_df.groupby(['연도'])['평당 분양가격'].mean().sort_values(ascending=False).to_frame()

# %%
yp.plot.bar(rot = 0,figsize=(5,5))
# Out:
# <AxesSubplot:xlabel='연도'>

# %%
# boxplot으로 만들기

# %%
g = last_df.pivot_table(index='연도',values='평당 분양가격') # ctrl+shift+-: 커서가 위치한 곳에서 분리됨

# %%
g
# Out:
#            평당 분양가격
# 연도
# 2015   9202.735802
# 2016   9683.025000
# 2017  10360.487653
# 2018  10978.938411
# 2019  12188.293092

# %%
g.T.plot.box() # T: 인덱스를 컬럼으로 보냄/
# Out:
# <AxesSubplot:>

# %%
g = last_df.pivot_table(columns='연도',index='월',values='평당 분양가격')
g
# Out:
# 연도         2015          2016          2017          2018          2019
# 월
# 1           NaN   9334.029630  10095.132143  10719.148000  11535.540789
# 2           NaN   9361.440000  10110.885714  10766.668000  11574.793421
# 3           NaN   9423.276923  10107.428571  10905.488000  11610.094737
# 4           NaN   9601.993902  10217.232143  10920.728571  11777.876000
# 5           NaN   9602.396341  10358.819277  11087.485714  11976.394737
# 6           NaN   9676.042683  10431.618072  10921.928571  12401.884000
# 7           NaN   9700.551220  10549.536585  10868.376316  12424.852000
# 8           NaN   9719.023171  10564.869512  10811.147368  12523.896000
# 9           NaN   9737.656098  10583.601266  10915.257692  12527.571429
# 10  9086.488889   9924.225882  10399.845570  11133.269231  12619.073077
# 11  9218.122222   9972.757143           NaN  11224.762025  12647.785714
# 12  9303.596296  10092.264286  10597.620000  11453.822368  12622.847368

# %%
g.plot.box(figsize = (10,3))
# Out:
# <AxesSubplot:>

# %%
#연도별 전용면적별 평당 분당가격, x에 전용면적이

# %%
g = last_df.pivot_table(columns='전용면적',index = '연도', values='평당 분양가격').plot.box(figsize=(10,3))
g
# Out:
# <AxesSubplot:>

# %%
g = last_df.pivot_table(index = '연도', values='평당 분양가격')
g['평당 분양가격'].plot.pie(shadow=True,radius=0.8) # pie는 값 하나만 필요해서 데이터프레임아니고 하나의 시리즈만 선택/shadow: 그림자/radius: 크기
# Out:
# <AxesSubplot:ylabel='평당 분양가격'>

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=last_df,x='지역명',y='평당 분양가격',ci = 'sd') #ci: 분산이 선으로
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당 분양가격'>

# %%
sns.catplot(data=last_df,x='연도',y= '평당 분양가격',kind='swarm',col='지역명',col_wrap=4) #catplot: 범주형 변수와 수(치)형 변수간 관계 시각화

# %%
sns.relplot(data=last_df,x='연도',y='평당 분양가격',kind='line',hue='월',col='지역명',col_wrap=4)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=last_df,x='연도',y='평당 분양가격',hue='지역명')
plt.legend(bbox_to_anchor=(1,1),loc=1) # 범례 조절/ 기준점/ 위치

# %%
first_df.head(2)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
#
# [2 rows x 22 columns]

# %%
pd.options.display.max_columns = 25

# %%
first_df.head(2)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
#
#    2014년7월  2014년8월  2014년9월  2014년10월  2014년11월  2014년12월  2015년1월  2015년2월  \
# 0    18742    19274    19404     19759     20242     20269    20670    20670
# 1     9457     9411     9258      9110      9208      9208     9204     9235
#
#    2015년3월  2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    19415    18842    18367    18374    18152    18443
# 1     9279     9327     9345     9515     9559     9581

# %%
pd.options.display.max_rows=20

# %%
last_df
# Out:
#      지역명    연도   월    분양가격  평당 분양가격        전용면적
# 0     서울  2015  10  5841.0  19275.3          전체
# 1     서울  2015  10  5652.0  18651.6         60㎡
# 2     서울  2015  10  5882.0  19410.6   60㎡ ~ 85㎡
# 3     서울  2015  10  5721.0  18879.3  85㎡ ~ 102㎡
# 4     서울  2015  10  5879.0  19400.7      102㎡ ~
# ...   ..   ...  ..     ...      ...         ...
# 4330  제주  2019  12  3882.0  12810.6          전체
# 4331  제주  2019  12     NaN      NaN         60㎡
# 4332  제주  2019  12  3898.0  12863.4   60㎡ ~ 85㎡
# 4333  제주  2019  12     NaN      NaN  85㎡ ~ 102㎡
# 4334  제주  2019  12  3601.0  11883.3      102㎡ ~
#
# [4335 rows x 6 columns]

# %%
# melt를 이용하여 월별 데이터를 '기간' 칼럼으로 가격은 '평당 분양가격'으로

# %%
first_df_melt = first_df.melt(id_vars='지역',var_name='기간',value_name='평당 분양가격')
first_df_melt.head(2)
# Out:
#    지역        기간  평당 분양가격
# 0  서울  2013년12월    18189
# 1  부산  2013년12월     8111

# %%
# 기간 칼럼의 값을 '연도', '월'로 분리

# %%
first_df_melt['연도'] = first_df_melt['기간'].str.split('년').str.get(0).astype(int)

# %%
first_df_melt['월'] = first_df_melt['기간'].str.split('년').str.get(1).str.replace('월','').astype(int)

# %%
first_df_melt.head()
# Out:
#    지역        기간  평당 분양가격    연도   월
# 0  서울  2013년12월    18189  2013  12
# 1  부산  2013년12월     8111  2013  12
# 2  대구  2013년12월     8080  2013  12
# 3  인천  2013년12월    10204  2013  12
# 4  광주  2013년12월     6098  2013  12

# %%
# last_df 전용면적에서 전체만 가지고 와 last_df_prepare로 저장

# %%
last_df_prepare = last_df[last_df['전용면적'] == '전체'].copy() # 원본은 놔두고 복사함

# %%
last_df_prepare.head()
# Out:
#    지역명    연도   월    분양가격  평당 분양가격 전용면적
# 0   서울  2015  10  5841.0  19275.3   전체
# 5   인천  2015  10  3163.0  10437.9   전체
# 10  경기  2015  10  3138.0  10355.4   전체
# 15  부산  2015  10  3112.0  10269.6   전체
# 20  대구  2015  10  2682.0   8850.6   전체

# %%
last_df_prepare.rename(columns ={'지역명':'지역'},inplace=True) # rename: 컬럼의 이름 변경/ inplace: 원본에 적용 여부

# %%
last_df_prepare.head(2)
# Out:
#    지역    연도   월    분양가격  평당 분양가격 전용면적
# 0  서울  2015  10  5841.0  19275.3   전체
# 5  인천  2015  10  3163.0  10437.9   전체

# %%
# concat으로 데이터 합치기

# %%
first = first_df_melt[['지역','연도','월','평당 분양가격']]
last = last_df_prepare[['지역','연도','월','평당 분양가격']]

# %%
df = pd.concat([first,last])

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#       지역    연도   월  평당 분양가격
# 0     서울  2013  12  18189.0
# 1     부산  2013  12   8111.0
# 2     대구  2013  12   8080.0
# 3     인천  2013  12  10204.0
# 4     광주  2013  12   6098.0
# ...   ..   ...  ..      ...
# 1219  전북  2019  12   8144.4
# 1220  전남  2019  12   8091.6
# 1221  경북  2019  12   9616.2
# 1222  경남  2019  12  10107.9
# 1223  제주  2019  12  12810.6
#
# [1224 rows x 4 columns]

# %%
df.groupby(['연도','월','지역']).count()
# Out:
#             평당 분양가격
# 연도   월  지역
# 2013 12 강원        1
#         경기        1
#         경남        1
#         경북        1
#         광주        1
# ...             ...
# 2019 12 전남        1
#         전북        1
#         제주        1
#         충남        1
#         충북        1
#
# [1224 rows x 1 columns]

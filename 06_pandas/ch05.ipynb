# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/concat_1.csv')
df2 = pd.read_csv('data/concat_2.csv')
df3 = pd.read_csv('data/concat_3.csv')

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
df2
# Out:
#     A   B   C   D
# 0  a4  b4  c4  d4
# 1  a5  b5  c5  d5
# 2  a6  b6  c6  d6
# 3  a7  b7  c7  d7

# %%
df3
# Out:
#      A    B    C    D
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3])
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
row_Series = pd.Series(['n1','n2','n3','n4'])

# %%
pd.concat([df1,row_Series],axis=1)
# Out:
#     A   B   C   D   0
# 0  a0  b0  c0  d0  n1
# 1  a1  b1  c1  d1  n2
# 2  a2  b2  c2  d2  n3
# 3  a3  b3  c3  d3  n4

# %%
new_df=pd.DataFrame({'A':['n1'], 
               'B':['n2'],
               'C':['n3'], 
               'D':['n4']} )
#위, 아래로 붙이려면 칼럼을 딕셔너리나 리스트로

# %%
pd.concat([df1,new_df])
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 0  n1  n2  n3  n4

# %%
df1.append(new_df)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5948\1631729507.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(new_df)
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 0  n1  n2  n3  n4

# %%
pd.concat([df1,df2,df3],ignore_index=False, axis=1)['A'] # ignore_index=True 시 인덱스 새로 부여
# Out:
#     A   A    A
# 0  a0  a4   a8
# 1  a1  a5   a9
# 2  a2  a6  a10
# 3  a3  a7  a11

# %%
df1.columns = ['A','B','C','D']
df2.columns = ['E','F','G','H']
df3.columns = ['A','C','F','H']

# %%
pd.concat([df1,df3],ignore_index=False,join='inner')
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 0   a8   b8
# 1   a9   b9
# 2  a10  b10
# 3  a11  b11

# %%
person = pd.read_csv('data/survey_person.csv')
site = pd.read_csv('data/survey_site.csv')
survey = pd.read_csv('data/survey_survey.csv')
visited = pd.read_csv('data/survey_visited.csv')

# %%
person
# Out:
#       ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
survey
# Out:
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# 19    837    roe   sal    22.50
# 20    844    roe   rad    11.25

# %%
visited
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 1    622   DR-1  1927-02-10
# 2    734   DR-3  1939-01-07
# 3    735   DR-3  1930-01-12
# 4    751   DR-3  1930-02-26
# 5    752   DR-3         NaN
# 6    837  MSK-4  1932-01-14
# 7    844   DR-1  1932-03-22

# %%
visited_subset = visited.loc[[0,2,6],]

# %%
visited_subset
# Out:
#    ident   site       dated
# 0    619   DR-1  1927-02-08
# 2    734   DR-3  1939-01-07
# 6    837  MSK-4  1932-01-14

# %%
pd.merge(site,visited_subset,left_on='name',right_on='site')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
pd.merge(site,visited_subset,left_on='name',right_on='site', how='outer')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
site.merge(visited_subset,left_on='name',right_on='site', how='inner')
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
ps=person.merge(survey,left_on='ident',right_on='person')

# %%
vs=visited.merge(survey,left_on='ident',right_on='taken')

# %%
ps.merge(vs,
         left_on=['ident','taken','quant','reading'],
        right_on=['person','ident','quant','reading'])
# Out:
#    ident_x   personal   family  taken_x person_x quant  reading  ident_y  \
# 0     dyer    William     Dyer      619     dyer   rad     9.82      619
# 1     dyer    William     Dyer      619     dyer   sal     0.13      619
# 2     dyer    William     Dyer      622     dyer   rad     7.80      622
# 3     dyer    William     Dyer      622     dyer   sal     0.09      622
# 4       pb      Frank  Pabodie      734       pb   rad     8.41      734
# 5       pb      Frank  Pabodie      734       pb  temp   -21.50      734
# 6       pb      Frank  Pabodie      735       pb   rad     7.22      735
# 7       pb      Frank  Pabodie      751       pb   rad     4.35      751
# 8       pb      Frank  Pabodie      751       pb  temp   -18.50      751
# 9     lake   Anderson     Lake      734     lake   sal     0.05      734
# 10    lake   Anderson     Lake      751     lake   sal     0.10      751
# 11    lake   Anderson     Lake      752     lake   rad     2.19      752
# ...
